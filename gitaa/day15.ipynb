# %%
#day15

# %%
#syntax error
print 'hello world'
# Out:
#   Cell In[3], line 2
#     print 'hello world'   # ❌ Missing parentheses
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print('hello world')
# Out:
# hello world

# %%
#name error
print(age)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 #name error
# ----> 2 print(age)
#
# NameError: name 'age' is not defined

# %%
age = 25
print(age)
# Out:
# 25

# %%
#index error
numbers = [1, 2, 3, 4, 5]
print(numbers[5])   # ❌ Only 0–4 exist
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 3
#       1 #index error
#       2 numbers = [1, 2, 3, 4, 5]
# ----> 3 print(numbers[5])
#
# IndexError: list index out of range

# %%
print(numbers[4])
# Out:
# 5

# %%
#module not found  error
import maths
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[47], line 2
#       1 #module not found  error
# ----> 2 import maths
#
# ModuleNotFoundError: No module named 'maths'

# %%
import math

# %%
#attribute error
import math
print(math.PI)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 3
#       1 #attribute error
#       2 import math
# ----> 3 print(math.PI)
#
# AttributeError: module 'math' has no attribute 'PI'

# %%
print(math.pi)
# Out:
# 3.141592653589793

# %%
#key error
user = {'name': 'Asab', 'age': 250}
print(user['country'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 3
#       1 #key error
#       2 user = {'name': 'Asab', 'age': 250}
# ----> 3 print(user['country'])
#
# KeyError: 'country'

# %%
print(user.get('country', 'Key not found'))
# Out:
# Key not found

# %%
#type error
4+'3'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 #type error
# ----> 2 4+'3'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
4+int('3')
# Out:
# 7

# %%
#import error
from math import power
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[35], line 2
#       1 #import error
# ----> 2 from math import power
#
# ImportError: cannot import name 'power' from 'math' (unknown location)

# %%
from math import pow
print(pow(2, 3))
# Out:
# 8.0

# %%
#value error
int('12a')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 2
#       1 #value error
# ----> 2 int('12a')
#
# ValueError: invalid literal for int() with base 10: '12a'

# %%
int('12')
# Out:
# 12

# %%
#zero division error 
1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[43], line 2
#       1 #zero division error
# ----> 2 1 / 0
#
# ZeroDivisionError: division by zero

# %%
1 / 2
# Out:
# 0.5
