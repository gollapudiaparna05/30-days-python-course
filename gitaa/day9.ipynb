# %%
#day 9

# %%
'''
Get user input using input("Enter your age: ").
If user is 18 or older, print "You are old enough to learn to drive."
If below 18, print how many years left to learn to drive.
'''
age = int(input("Enter your age: "))
if age >= 18:
    print("You are old enough to learn to drive.")
else:
    print(f"You need {18 - age} more years to learn to drive.")
# Out:
# Enter your age:  20
# You are old enough to learn to drive.

# %%
'''
Compare the values of my_age and your_age using input.
Print who is older and by how many years.
'''
my_age = 25
your_age = int(input("Enter your age: "))
if your_age > my_age:
    diff = your_age - my_age
    if diff == 1:
        print(f"You are {diff} year older than me.")
    else:
        print(f"You are {diff} years older than me.")
elif your_age < my_age:
    diff = my_age - your_age
    if diff == 1:
        print(f"I am {diff} year older than you.")
    else:
        print(f"I am {diff} years older than you.")
else:
    print("We are the same age.")
# Out:
# Enter your age:  20
# I am 5 years older than you.

# %%
'''
Get two numbers from the user.
Compare which one is greater, smaller or equal.
'''
a = int(input("Enter number one: "))
b = int(input("Enter number two: "))
if a > b:
    print(f"{a} is greater than {b}")
elif a < b:
    print(f"{a} is smaller than {b}")
else:
    print(f"{a} is equal to {b}")
# Out:
# Enter number one:  5
# Enter number two:  8
# 5 is smaller than 8

# %%
'''
Write a code which gives grade to students according to their scores:
80-100 = A, 70-89 = B, 60-69 = C, 50-59 = D, 0-49 = F
'''
score = int(input("Enter your score: "))
if 80 <= score <= 100:
    print("A")
elif 70 <= score <= 89:
    print("B")
elif 60 <= score <= 69:
    print("C")
elif 50 <= score <= 59:
    print("D")
elif 0 <= score <= 49:
    print("F")
else:
    print("Invalid score")
# Out:
# Enter your score:  95
# A

# %%
'''
Check the season from user input (month name)
Autumn: September, October, November
Winter: December, January, February
Spring: March, April, May
Summer: June, July, August
'''
month = input("Enter month: ").capitalize()
if month in ['September', 'October', 'November']:
    print("The season is Autumn.")
elif month in ['December', 'January', 'February']:
    print("The season is Winter.")
elif month in ['March', 'April', 'May']:
    print("The season is Spring.")
elif month in ['June', 'July', 'August']:
    print("The season is Summer.")
else:
    print("Invalid month.")
# Out:
# Enter month:  April
# The season is Spring.

# %%
'''
Check if fruit exists in list, if not add it, else print message.
'''
fruits = ['banana', 'orange', 'mango', 'lemon']
fruit = input("Enter a fruit: ").lower()
if fruit in fruits:
    print("That fruit already exists in the list.")
else:
    fruits.append(fruit)
    print(fruits)
# Out:
# Enter a fruit:  guava
# ['banana', 'orange', 'mango', 'lemon', 'guava']

# %%
'''
Check if the person dictionary has skills key, print middle skill if present.
'''
person = {
    'first_name': 'gollapudi',
    'last_name': 'aparna',
    'age': 250,
    'country': 'Finland',
    'is_marred': True,
    'skills': ['JavaScript', 'React', 'Node', 'MongoDB', 'Python'],
    'address': {
        'street': 'Space street',
        'zipcode': '02210'
    }
}
if 'skills' in person:
    skills = person['skills']
    print(skills[len(skills)//2])
# Out:
# Node

# %%
'''
Check if the person dictionary has 'Python' in skills
'''
if 'skills' in person:
    print('Python' in person['skills'])
# Out:
# True

# %%
'''
Check developer type based on skill combination
'''
skills = person['skills']
if set(skills) == {'JavaScript', 'React'}:
    print('He is a front end developer')
elif {'Node', 'Python', 'MongoDB'}.issubset(skills):
    print('He is a backend developer')
elif {'React', 'Node', 'MongoDB'}.issubset(skills):
    print('He is a fullstack developer')
else:
    print('Unknown title')
# Out:
# He is a backend developer

# %%
'''
If the person is married and lives in Finland, print formatted information
'''
if person['is_marred'] and person['country'] == 'Finland':
    print(f"{person['first_name']} {person['last_name']} lives in {person['country']}. she is married.")
# Out:
# gollapudi aparna lives in Finland. she is married.
