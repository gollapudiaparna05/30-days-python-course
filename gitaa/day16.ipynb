# %%
#day16

# %%
from datetime import datetime, date

now = datetime.now()
print("Current day:", now.day)
print("Current month:", now.month)
print("Current year:", now.year)
print("Current hour:", now.hour)
print("Current minute:", now.minute)
print("Current timestamp:", now.timestamp())
# Out:
# Current day: 11
# Current month: 11
# Current year: 2025
# Current hour: 15
# Current minute: 26
# Current timestamp: 1762854961.181321

# %%
formatted_date = now.strftime("%m/%d/%Y, %H:%M:%S")
print(formatted_date)
# Out:
# 11/11/2025, 15:26:01

# %%
from datetime import datetime
time_string = "5 December, 2019"
converted_time = datetime.strptime(time_string, "%d %B, %Y")
print(converted_time)
# Out:
# 2019-12-05 00:00:00

# %%
from datetime import datetime
new_year = datetime(now.year + 1, 1, 1)
time_diff = new_year - now
print("Time until New Year:", time_diff)
# Out:
# Time until New Year: 50 days, 8:33:58.818679
