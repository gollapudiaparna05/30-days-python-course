# %%
#day 4

# %%
'''
Question 1:
Concatenate 'Thirty', 'Days', 'Of', 'Python' to form 'Thirty Days Of Python'.
'''
a = 'Thirty'
b = 'Days'
c = 'Of'
d = 'Python'
result = a + ' ' + b + ' ' + c + ' ' + d
print(result)
# Out:
# Thirty Days Of Python

# %%
'''
Question 2:
Concatenate 'Coding', 'For', 'All' to form 'Coding For All'.
'''

result = 'Coding' + ' ' + 'For'+ ' ' + 'All'
print(result)
# Out:
# Coding For All

# %%
'''
Question 3:
Declare variable c = "Coding For All"
'''
c = "Coding For All"
print(c)
# Out:
# Coding For All

# %%
'''
Question 4:
Print length of c
'''
print(len(c))
# Out:
# 14

# %%
'''
Question 5:
Convert all characters to uppercase
'''
print(c.upper())
# Out:
# CODING FOR ALL

# %%
'''
Question 6:
Convert all characters to lowercase
'''
print(c.lower())
# Out:
# coding for all

# %%
'''
Question 7:
Use capitalize(), title(), swapcase()
'''
print(c.capitalize())
print(c.title())
print(c.swapcase())
# Out:
# Coding for all
# Coding For All
# cODING fOR aLL

# %%
'''
Question 8:
Cut out the first word from "Coding For All"
'''
print(c[7:])
# Out:
# For All

# %%
'''
Question 9:
Check if "Coding For All" contains the word "Coding"
'''
print('Coding' in c)
# Out:
# True

# %%
'''
Question 10:
Replace "Coding" with "Python"
'''
print(c.replace('Coding', 'Python'))
# Out:
# Python For All

# %%
'''
Question 12:
Split "Coding For All" using space
'''
print(c.split())
# Out:
# ['Coding', 'For', 'All']

# %%
'''
Question 13:
Split "Facebook, Google, Microsoft, Apple, IBM, Oracle, Amazon" by comma
'''
companies = "Facebook, Google, Microsoft, Apple, IBM, Oracle, Amazon"
print(companies.split(','))
# Out:
# ['Facebook', ' Google', ' Microsoft', ' Apple', ' IBM', ' Oracle', ' Amazon']

# %%
'''
Question 14:
What is the character at index 0 in "Coding For All"
'''
print(c[0])
# Out:
# C

# %%
'''
Question 15:
What is the last index of "Coding For All"
'''
print(len(c) - 1)
# Out:
# 13

# %%
'''
Question 16:
What character is at index 10
'''
print(c[10])

# %%
'''
Question 17:
Create acronym for "Coding For All"
'''
text = 'Coding For All'
acronym = ''.join(word[0] for word in text.split())
print(acronym)
# Out:
# CFA

# %%
'''
Question 17:
Create acronym for "Python For Everyone"
'''
text = 'Python For Everyone'
acronym = ''.join(word[0] for word in text.split())
print(acronym)
# Out:
# PFE

# %%
'''
Question 19:
Use index to find first occurrence of 'C'
'''
print(c.index('C'))
# Out:
# 0

# %%
'''
Question 20:
Use index to find first occurrence of 'F'
'''
print(c.index('F'))
# Out:
# 7

# %%
'''
Question 21:
Use rfind to find position of last occurrence of 'l' in "Coding For All People"
'''
text = 'Coding For All People'
print(text.rfind('l'))
# Out:
# 19

# %%
'''
Question 22:
Find first occurrence of "because" in sentence
'''
sentence = 'You cannot end a sentence with because because because is a conjunction'
print(sentence.find('because'))
# Out:
# 31

# %%
'''
Question 23:
Find last occurrence of "because" using rindex
'''
print(sentence.rindex('because'))
# Out:
# 47

# %%
'''
Question 24:
Slice out 'because because because'
'''
start = sentence.find('because')
end = sentence.rindex('because') + len('because')
print(start,end)
print(sentence[start:end])
# Out:
# 31 54
# because because because

# %%
'''
Question 25:
Does "Coding For All" start with "Coding"?
'''
print(c.startswith('Coding'))
# Out:
# True

# %%
'''
Question 26:
Does "Coding For All" end with "coding"?
'''
print(c.endswith('coding'))
# Out:
# False

# %%
'''
Question 27:
Remove left and right trailing spaces
'''
text = '   Coding For All      '
print(text.strip())
# Out:
# Coding For All

# %%
'''
Question 28:
Which isidentifier() returns True?
'''
print('30DaysOfPython'.isidentifier())
print('thirty_days_of_python'.isidentifier())
# Out:
# False
# True

# %%
'''
Question 29:
Join python libraries list with '# ' separator
'''
libs = ['Django', 'Flask', 'Bottle', 'Pyramid', 'Falcon']
print('# '.join(libs))
# Out:
# Django# Flask# Bottle# Pyramid# Falcon

# %%
'''
Question 30:
Use newline escape sequence
'''
print("I am enjoying this challenge.\nI just wonder what is next.")
# Out:
# I am enjoying this challenge.
# I just wonder what is next.

# %%
'''
Question 31:
Use tab escape sequence
'''
print("Name\tAge\tCountry\tCity\nAsabeneh\t250\tFinland\tHelsinki")
# Out:
# Name	Age	Country	City
# Asabeneh	250	Finland	Helsinki

# %%
'''
Question 32:
Use string formatting to display circle area
'''
radius = 10
area = 3.14 * radius ** 2
print("The area of a circle with radius {} is {} meters square.".format(radius, int(area)))
# Out:
# The area of a circle with radius 10 is 314 meters square.

# %%
'''
Question 33:
Use string formatting for arithmetic operations
'''
a, b = 8, 6
print('{} + {} = {}'.format(a, b, a + b))
print('{} - {} = {}'.format(a, b, a - b))
print('{} * {} = {}'.format(a, b, a * b))
print('{} / {} = {:.2f}'.format(a, b, a / b))
print('{} % {} = {}'.format(a, b, a % b))
print('{} // {} = {}'.format(a, b, a // b))
print('{} ** {} = {}'.format(a, b, a ** b))
# Out:
# 8 + 6 = 14
# 8 - 6 = 2
# 8 * 6 = 48
# 8 / 6 = 1.33
# 8 % 6 = 2
# 8 // 6 = 1
# 8 ** 6 = 262144
